# %%
import pandas as pd

# %%
achievement = pd.read_csv('data/8.수학지식체계_데이터셋/achievements.csv')
print(achievement.info())
print("성취기준 csv 첫번째 5행: \n",achievement.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 378 entries, 0 to 377
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      378 non-null    int64
#  1   name    378 non-null    str
# dtypes: int64(1), str(1)
# memory usage: 36.3 KB
# None
# 성취기준 csv 첫번째 5행:
#      id                                  name
# 0    1    50까지의 수 개념을이해 하고, 수를 세고 읽고 쓸 수 있다.
# 1   10             10000 이상의 큰 수를 읽고 쓸 수 있다.
# 2  100             일차부등식을 활용하여 문제를 해결할 수 있다.
# 3  101             미지수가 2개인 연립일차방정식을 풀 수 있다.
# 4  102  미지수가 2개인 연립일차방정식을 활용하여 문제를 해결할 수 있다.

# %%
chapters = pd.read_csv('data/8.수학지식체계_데이터셋/chapters.csv')
print(chapters.info())
print("\n단원 csv 첫번째 5행: \n",chapters.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      646 non-null    int64
#  1   name    646 non-null    str
# dtypes: int64(1), str(1)
# memory usage: 48.6 KB
# None
#
# 단원 csv 첫번째 5행:
#      id                        name
# 0    1           9까지의 수 > 몇일까요 (1)
# 1   10  여러 가지 모양 > 여러 가지 모양을 알아볼까요
# 2  100       분류하기 > 기준에 따라 분류해 볼까요
# 3  101          분류하기 > 분류하여 세어 볼까요
# 4  102       분류하기 > 분류한 결과를 말해 볼까요

# %% [markdown]
# chapters

# %%
concepts = pd.read_csv('data/8.수학지식체계_데이터셋/concepts.csv')
print(concepts.info())
print("\n단원 csv 첫번째 5행: \n",concepts.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1631 entries, 0 to 1630
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              1631 non-null   int64
#  1   name            1631 non-null   str
#  2   semester        1631 non-null   str
#  3   description     1623 non-null   str
#  4   chapter_id      1629 non-null   float64
#  5   achievement_id  1624 non-null   float64
# dtypes: float64(2), int64(1), str(3)
# memory usage: 576.1 KB
# None
#
# 단원 csv 첫번째 5행:
#     id                   name   semester  \
# 0   3       지수가 자연수일 때의 지수법칙   고등-수1-전체
# 1   4                  거듭제곱근   고등-수1-전체
# 2  10           거듭제곱근의 대소 비교   고등-수1-전체
# 3  23         이등변삼각형의 밑각의 성질  중등-중2-2학기
# 4  24  이등변삼각형의 꼭지각의 이등분선의 성질  중등-중2-2학기
#
#                                          description  chapter_id  \
# 0  $a$, $b$가 실수이고 $m$, $n$이 자연수일 때\n\n(1)$a^ma^n=...       587.0
# ...
